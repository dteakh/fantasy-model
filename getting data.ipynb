# %%
import fantasy as fp
# noinspection PyUnresolvedReferences
from fantasyalgo import best_subset
import datetime as dt
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
start = dt.date(2022, 1, 1)
end = dt.date.today()
delta = dt.timedelta(days=90)

events = [6586, 6140, 6136, 6621, 6370]
cur = 0

dataframes = []
used = []

for key in events:

    event = fp.Event(key)
    players = event.get_players()

    for p in players:
        if p.key not in used:
            used.append(p.key)
            dataframes.append(p.get_dataset(start, end, delta))

    cur += 1
# Out:
# TESTING: karrigan
# GETTING: karrigan --> 6138
# GETTING: karrigan --> 6372
# GETTING: karrigan --> 6343
# GETTING: karrigan --> 6345
# GETTING: karrigan --> 6346
# GETTING: karrigan --> 6219
# GETTING: karrigan --> 6348
# GETTING: karrigan --> 6349
# GETTING: karrigan --> 6510
# GETTING: karrigan --> 6381
# GETTING: karrigan --> 6137
# GETTING: karrigan --> 6136
# GETTING: karrigan --> 6713
# GETTING: karrigan --> 6586
# GETTING: karrigan --> 6140
# GETTING: karrigan --> 6141
# TOTAL EVENTS: 16
# OK: 16
# FAILED: 0
# TESTING: rain
# GETTING: rain --> 6138
# GETTING: rain --> 6372
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2449/4145960372.py in <module>
#      17         if p.key not in used:
#      18             used.append(p.key)
# ---> 19             dataframes.append(p.get_dataset(start, end, delta))
#      20
#      21     cur += 1
#
# ~/fantasy-model/fantasy.py in handler(*args, **kwargs)
#      31                 time.sleep(timeout - delta)
#      32             last_call = time.time()
# ---> 33             return f(*args, **kwargs)
#      34
#      35         return handler
#
# ~/fantasy-model/fantasy.py in get_dataset(self, start, end, delta)
#     166                 _pts = self.calc_pts(_key)
#     167
# --> 168                 _all_rating = self.get_stats(_event.start - delta, _event.start - dt.timedelta(1), EventFilter.ALL)
#     169                 _big_rating = self.get_stats(_event.start - delta, _event.start - dt.timedelta(1), EventFilter.BIG)
#     170
#
# ~/fantasy-model/fantasy.py in handler(*args, **kwargs)
#      31                 time.sleep(timeout - delta)
#      32             last_call = time.time()
# ---> 33             return f(*args, **kwargs)
#      34
#      35         return handler
#
# ~/fantasy-model/fantasy.py in get_stats(self, start, end, fil)
#     109
#     110         _url = self.stats_link(start.strftime('%Y-%m-%d'), end.strftime('%Y-%m-%d'), fil)
# --> 111         _src = BeautifulSoup(requests.get(_url, headers=HEADERS).text, "lxml")
#     112         _stats = _src.find("div", class_="summary").find_all("div", class_="value")
#     113
#
# ~/.local/lib/python3.10/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331             self.builder.initialize_soup(self)
#     332             try:
# --> 333                 self._feed()
#     334                 success = True
#     335                 break
#
# ~/.local/lib/python3.10/site-packages/bs4/__init__.py in _feed(self)
#     449         self.builder.reset()
#     450
# --> 451         self.builder.feed(self.markup)
#     452         # Close out any unfinished strings and close all the open tags.
#     453         self.endData()
#
# ~/.local/lib/python3.10/site-packages/bs4/builder/_lxml.py in feed(self, markup)
#     377             self.parser = self.parser_for(encoding)
#     378             self.parser.feed(markup)
# --> 379             self.parser.close()
#     380         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#     381             raise ParserRejectedMarkup(e)
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.close()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.close()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxEndNoNs()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxEnd()
#
# ~/.local/lib/python3.10/site-packages/bs4/builder/_lxml.py in end(self, name)
#     314
#     315     def end(self, name):
# --> 316         self.soup.endData()
#     317         completed_tag = self.soup.tagStack[-1]
#     318         namespace, name = self._getNsTag(name)
#
# ~/.local/lib/python3.10/site-packages/bs4/__init__.py in endData(self, containerClass)
#     588             containerClass = self.string_container(containerClass)
#     589             o = containerClass(current_data)
# --> 590             self.object_was_parsed(o)
#     591
#     592     def object_was_parsed(self, o, parent=None, most_recent_element=None):
#
# ~/.local/lib/python3.10/site-packages/bs4/__init__.py in object_was_parsed(self, o, parent, most_recent_element)
#     594         if parent is None:
#     595             parent = self.currentTag
# --> 596         if most_recent_element is not None:
#     597             previous_element = most_recent_element
#     598         else:
#
# KeyboardInterrupt:

# %%
dataframes[0]
# Out:
#       player                                event   avg rank  \
# 0   karrigan                      IEM Dallas 2022  15.812000
# 1   karrigan               PGL Major Antwerp 2022  11.250000
# 2   karrigan     BLAST Premier Spring Groups 2022  33.272999
# 3   karrigan      BLAST Premier Spring Final 2022  10.500000
# 4   karrigan       BLAST Premier Fall Groups 2022  29.083000
# 5   karrigan            IEM Katowice 2022 Play-In  21.000000
# 6   karrigan        BLAST Premier Fall Final 2022  11.750000
# 7   karrigan       BLAST Premier World Final 2022   7.125000
# 8   karrigan                      Roobet Cup 2022  17.125000
# 9   karrigan  PGL Major Antwerp 2022 Europe RMR A  29.750000
# 10  karrigan             ESL Pro League Season 15  25.695999
# 11  karrigan                    IEM Katowice 2022  13.438000
# 12  karrigan    IEM Road to Rio 2022 Europe RMR A  25.625000
# 13  karrigan                   IEM Rio Major 2022  10.750000
# 14  karrigan                     IEM Cologne 2022  10.062000
# 15  karrigan             ESL Pro League Season 16  16.917000
#
#     all events rating  big events rating   pts
# 0                0.91               0.89 -49.0
# 1                0.91               0.89  67.0
# 2                0.91               0.89 -46.0
# 3                0.91               0.89 -34.0
# 4                0.91               0.89 -50.0
# 5                0.91               0.89  -1.0
# 6                0.91               0.89   3.0
# 7                0.91               0.89 -43.0
# 8                0.91               0.89 -34.0
# 9                0.91               0.89  28.0
# 10               0.91               0.89 -39.0
# 11               0.91               0.89   4.0
# 12               0.91               0.89  19.0
# 13               0.91               0.89 -41.0
# 14               0.91               0.89   6.0
# 15               0.91               0.89 -87.0
